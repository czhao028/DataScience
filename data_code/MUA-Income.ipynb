# %%
import pandas as pd

# %%
mua = pd.read_csv(r'C:\Users\Adelle Jia\Downloads\MUA_DET.csv')
mua_part = mua['MUA/P Status Code', ]
# Out:
#          MUA/P ID  MUA/P Area Code  Minor Civil Division FIPS Code  \
# 0      1708832230            70002                             NaN
# 1      1708832230            70100                             NaN
# 2      1708832230            70218                             NaN
# 3      1708832230            70222                             NaN
# 4      1708832230            70214                             NaN
# 5      1708832230            70050                             NaN
# 6      1708832230            70004                             NaN
# 7      1708832230            70228                             NaN
# 8      1708832230            70350                             NaN
# 9      1708832230            70370                             NaN
# 10     1708832230            70010                             NaN
# 11     1708832230            70150                             NaN
# 12     1708832230            70212                             NaN
# ...

# %%
mua['MUA_DESIGNATION_TYP_DESC'].value_counts()
# Out:
# Medically Underserved Area                                     14430
# Medically Underserved Population                                3820
# Medically Underserved Area ?�ô Governor?�Ös Exception            601
# Medically Underserved Population ?�ô Governor?�Ös Exception      484
# Name: MUA_DESIGNATION_TYP_DESC, dtype: int64

# %%
mua2 = mua[mua['MUA_SCORE'] >70]
mua2
# Out:
#        MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 5551            1046  19193001400                    MUA
# 15323           2721        40009                    MUA
#
#          MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD MUA_STATUS_DESC  \
# 5551   Medically Underserved Area             D      Designated
# 15323  Medically Underserved Area             W       Withdrawn
#
#          CENSUS_TRACT MUA_DESIGNATION_DT MUA_DESIGNATION_DT_TXT  MUA_SCORE  \
# 5551               14         1994-05-24              5/24/1994       74.7
# 15323  Not Applicable         1978-11-01              11/1/1978       77.0
#
#        COUNTY_FIPS_CD LIST_BOX_COUNTY_NM COUNTY_NM  REGION_CD
# 5551              193    Woodbury County  Woodbury          7
# 15323               9     Beckham County   Beckham          6

# %%
#mua.drop(columns=['CENSUS_TRACT', 'MCD_FIPS_Cd','MCD_CENSUS_CD', 'MCD_NM' ])
mua.drop_duplicates(subset = "COUNTY_NM", inplace = True)
mua.head(10)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0             7899   1017954000                    MUA
# 70            4005   1097005700                    MUA
# 71              97   1073000800                    MUA
# 92              96   1125010102                    MUA
# 106             92   1103005500                    MUA
# 107             91   1101006000                    MUA
# 191             80   1089011200                    MUA
# 200             76   1083021100                    MUA
# 213             72   1077011802                    MUA
# 229             65   1055011100                    MUA
#
#        MUA_DESIGNATION_TYP_DESC MUA_STATUS_CD MUA_STATUS_DESC CENSUS_TRACT  \
# ...

# %%
mua
# Out:
#        MUA_SOURCE_ID  MUA_AREA_CD MUA_DESIGNATION_TYP_CD  \
# 0               7899   1017954000                    MUA
# 70              4005   1097005700                    MUA
# 71                97   1073000800                    MUA
# 92                96   1125010102                    MUA
# 106               92   1103005500                    MUA
# 107               91   1101006000                    MUA
# 191               80   1089011200                    MUA
# 200               76   1083021100                    MUA
# 213               72   1077011802                    MUA
# 229               65   1055011100                    MUA
# 258             7174   2261000300                    MUA
# 259              105   2020000703                    MUA
# 326             7678   4019005200                    MUA
# 327             7652   4013103306                    MUA
# 373             7456   4027011000                    MUA
# ...

# %%
income = pd.read_csv(r'C:\Users\Adelle Jia\Downloads\income_county.csv', skiprows=3)
income.head(10)
# Out:
#    State FIPS Code  County FIPS Code Postal Code            Name  \
# 0                0                 0          US   United States
# 1                1                 0          AL         Alabama
# 2                1                 1          AL  Autauga County
# 3                1                 3          AL  Baldwin County
# 4                1                 5          AL  Barbour County
# 5                1                 7          AL     Bibb County
# 6                1                 9          AL   Blount County
# 7                1                11          AL  Bullock County
# 8                1                13          AL   Butler County
# 9                1                15          AL  Calhoun County
#
#   Poverty Estimate, All Ages 90% CI Lower Bound 90% CI Upper Bound  \
# 0                 41,852,315         41,619,366         42,085,264
# 1                    801,758            785,668            817,848
# ...

# %%
income = income[income['County FIPS Code'] != 0]
incomepart = income[['Name', 'Postal Code','Poverty Percent, All Ages']]

# %%
incomepart
# Out:
#                     Name Postal Code Poverty Percent, All Ages
# 2         Autauga County          AL                      13.8
# 3         Baldwin County          AL                       9.8
# 4         Barbour County          AL                      30.9
# 5            Bibb County          AL                      21.8
# 6          Blount County          AL                      13.2
# 7         Bullock County          AL                      42.5
# 8          Butler County          AL                      24.5
# 9         Calhoun County          AL                      19.5
# 10       Chambers County          AL                      18.7
# 11       Cherokee County          AL                      16.3
# 12        Chilton County          AL                      17.3
# 13        Choctaw County          AL                      22.1
# 14         Clarke County          AL                      22.8
# 15           Clay County          AL                      17.6
# ...

# %%
incomepart.to_excel(r'C:\Users\Adelle Jia\Downloads\povertylevel.xlsx', index = False, header=True)
